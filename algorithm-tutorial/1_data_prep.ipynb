# %% [markdown]
# ## Step 1: Data Preparation

# %%
import os
from utils.dot2polygon import dot2polygon
import glob
import yaml

# %%
# make a folder for converted annotations
output_root = r'./data/annotations_polygon'
if not(os.path.isdir(output_root)): os.mkdir (output_root)

# %% [markdown]
# Convert the dot annotation to polygon bounding boxes

# %%
# # convert dot annotations to polygon, in a folder

annotation_dir = r'./data/annotations/xml'
annotation_polygon_dir = r'./data/annotations_polygon'
annotation_list = glob.glob(os.path.join(annotation_dir,'*.xml'))
for xml_path in annotation_list:
    print(xml_path)
    output_path = os.path.join(annotation_polygon_dir,os.path.splitext(os.path.basename(xml_path))[0] + '_polygon' + os.path.splitext(os.path.basename(xml_path))[1])
    print(output_path)
    lymphocyte_half_box_size = 4 # the size of half of the bbox around the lymphocyte dot in um
    monocytes_half_box_size =7 # the size of half of the bbox around the monocytes dot in um
    min_spacing = 0.3
    dot2polygon(xml_path, lymphocyte_half_box_size, monocytes_half_box_size, min_spacing, output_path)
#2.5 3
#2 2.5 0.25
#3, 3.75
# 4, 7
#4.5, 8
#
# Out:
# ./data/annotations/xml/C_P000021.xml
# ./data/annotations_polygon/C_P000021_polygon.xml
# ./data/annotations/xml/B_P000005.xml
# ./data/annotations_polygon/B_P000005_polygon.xml
# ./data/annotations/xml/A_P000035.xml
# ./data/annotations_polygon/A_P000035_polygon.xml
# ./data/annotations/xml/D_P000012.xml
# ./data/annotations_polygon/D_P000012_polygon.xml
# ./data/annotations/xml/A_P000007.xml
# ./data/annotations_polygon/A_P000007_polygon.xml
# ./data/annotations/xml/B_P000009.xml
# ./data/annotations_polygon/B_P000009_polygon.xml
# ./data/annotations/xml/C_P000035.xml
# ./data/annotations_polygon/C_P000035_polygon.xml
# ./data/annotations/xml/A_P000002.xml
# ./data/annotations_polygon/A_P000002_polygon.xml
# ./data/annotations/xml/B_P000014.xml
# ./data/annotations_polygon/B_P000014_polygon.xml
# ./data/annotations/xml/C_P000026.xml
# ./data/annotations_polygon/C_P000026_polygon.xml
# ./data/annotations/xml/C_P000040.xml
# ./data/annotations_polygon/C_P000040_polygon.xml
# ./data/annotations/xml/C_P000031.xml
# ./data/annotations_polygon/C_P000031_polygon.xml
# ./data/annotations/xml/A_P000021.xml
# ./data/annotations_polygon/A_P000021_polygon.xml
# ./data/annotations/xml/A_P000017.xml
# ./data/annotations_polygon/A_P000017_polygon.xml
# ./data/annotations/xml/D_P000009.xml
# ./data/annotations_polygon/D_P000009_polygon.xml
# ./data/annotations/xml/B_P000019.xml
# ./data/annotations_polygon/B_P000019_polygon.xml
# ./data/annotations/xml/A_P000003.xml
# ./data/annotations_polygon/A_P000003_polygon.xml
# ./data/annotations/xml/B_P000015.xml
# ./data/annotations_polygon/B_P000015_polygon.xml
# ./data/annotations/xml/A_P000006.xml
# ./data/annotations_polygon/A_P000006_polygon.xml
# ./data/annotations/xml/D_P000010.xml
# ./data/annotations_polygon/D_P000010_polygon.xml
# ./data/annotations/xml/A_P000037.xml
# ./data/annotations_polygon/A_P000037_polygon.xml
# ./data/annotations/xml/D_P000007.xml
# ./data/annotations_polygon/D_P000007_polygon.xml
# ./data/annotations/xml/A_P000014.xml
# ./data/annotations_polygon/A_P000014_polygon.xml
# ./data/annotations/xml/C_P000024.xml
# ./data/annotations_polygon/C_P000024_polygon.xml
# ./data/annotations/xml/C_P000028.xml
# ./data/annotations_polygon/A_P000033_polygon.xml
# ./data/annotations/xml/A_P000022.xml
# ./data/annotations_polygon/A_P000022_polygon.xml
# ./data/annotations/xml/B_P000016.xml
# ./data/annotations_polygon/B_P000016_polygon.xml
# ./data/annotations/xml/C_P000029.xml
# ./data/annotations_polygon/C_P000029_polygon.xml
# ./data/annotations/xml/B_P000007.xml
# ./data/annotations_polygon/B_P000007_polygon.xml
# ./data/annotations/xml/B_P000002.xml
# ./data/annotations_polygon/B_P000002_polygon.xml
# ./data/annotations/xml/A_P000031.xml
# ./data/annotations_polygon/A_P000031_polygon.xml
# ./data/annotations/xml/A_P000036.xml
# ./data/annotations_polygon/A_P000036_polygon.xml
# ./data/annotations/xml/C_P000030.xml
# ./data/annotations_polygon/C_P000030_polygon.xml
# ./data/annotations/xml/C_P000023.xml
# ./data/annotations_polygon/C_P000023_polygon.xml
# ./data/annotations/xml/D_P000019.xml
# ./data/annotations_polygon/D_P000019_polygon.xml
# ./data/annotations/xml/D_P000018.xml
# ./data/annotations_polygon/D_P000018_polygon.xml
# ./data/annotations/xml/C_P000038.xml
# ./data/annotations_polygon/C_P000038_polygon.xml
# ./data/annotations/xml/A_P000004.xml
# ./data/annotations_polygon/A_P000004_polygon.xml
# ./data/annotations/xml/D_P000017.xml
# ./data/annotations_polygon/D_P000017_polygon.xml
# ./data/annotations/xml/A_P000024.xml
# ./data/annotations_polygon/A_P000024_polygon.xml
# ./data/annotations/xml/A_P000029.xml
# ./data/annotations_polygon/A_P000029_polygon.xml
# ./data/annotations/xml/C_P000033.xml
# ./data/annotations_polygon/C_P000033_polygon.xml
# ./data/annotations/xml/A_P000030.xml
# ./data/annotations_polygon/A_P000030_polygon.xml
# ./data/annotations/xml/A_P000032.xml
# ./data/annotations_polygon/A_P000032_polygon.xml
# ./data/annotations/xml/D_P000011.xml
# ./data/annotations_polygon/D_P000011_polygon.xml

# %% [markdown]
# Creating the yaml config files for training.

# %%
def folders_to_yml(wsi_dir: str, 
                   wsa_dir: str,
                   output_dir: str,
                   output_name: str):

    """
    Generate a yaml file to be used as WSD dataconfig from a folder of slides and a folder of annotation or mask files.
    Assumes files use the same name for both the slides and masks.
    """
    
    wsa_list = glob.glob(wsa_dir)

    yaml_dict = {'training': []}
    #yaml_dict = {'training': [], 'validation': []}
    for wsa in wsa_list:
        patient_name = os.path.basename(wsa).split(os.path.basename(wsa_dir).split('*')[1])[0] # monocytes
        print(patient_name)
        if os.path.isfile(os.path.join(wsi_dir,patient_name + "_PAS_CPG.tif")):
            wsi = os.path.join(wsi_dir, patient_name + "_PAS_CPG.tif")
            print('match found:    ' , patient_name)
            yaml_dict['training'].append(
                    {"wsa": {"path": str(wsa)}, "wsi": {"path": str(wsi)}})
        else:
            print('no match found:    ' , patient_name)
            
    # for wsa in wsa_list[-8:]:
    #     patient_name = os.path.basename(wsa).split(os.path.basename(wsa_dir).split('*')[1])[0] # monocytes
    #     print(patient_name)
    #     if os.path.isfile(os.path.join(wsi_dir,patient_name + "_PAS_CPG.tif")):
    #         wsi = os.path.join(wsi_dir, patient_name + "_PAS_CPG.tif")
    #         print('match found:    ' , patient_name)

    #         # validation if needed
    #         yaml_dict['validation'].append(
    #                 {"wsa": {"path": str(wsa)}, "wsi": {"path": str(wsi)}})
    #     else:
    #         print('no match found:    ' , patient_name)

    # make a folder for output
    if not(os.path.isdir(output_dir)): os.mkdir (output_dir)


    with open(os.path.join(output_dir,output_name), "w") as file:
            yaml.safe_dump(yaml_dict, file)

# %%
wsi_dir = r'./data/images/pas-cpg/'
wsa_dir = r'./data/annotations_polygon/*_polygon.xml'
output_dir = r'./configs'
output_name = 'training_sample.yml'

folders_to_yml(wsi_dir, 
               wsa_dir,
               output_dir,
               output_name)
# Out:
# A_P000006
# match found:     A_P000006
# C_P000033
# match found:     C_P000033
# A_P000001
# match found:     A_P000001
# B_P000007
# match found:     B_P000007
# B_P000005
# match found:     B_P000005
# A_P000016
# match found:     A_P000016
# A_P000005
# match found:     A_P000005
# C_P000039
# match found:     C_P000039
# B_P000014
# match found:     B_P000014
# D_P000012
# match found:     D_P000012
# A_P000003
# match found:     A_P000003
# C_P000037
# match found:     C_P000037
# D_P000018
# match found:     D_P000018
# C_P000024
# match found:     C_P000024
# A_P000032
# match found:     A_P000032
# C_P000026
# match found:     C_P000026
# A_P000021
# match found:     A_P000021
# C_P000029
# match found:     C_P000029
# B_P000004
# match found:     B_P000004
# A_P000020
# match found:     A_P000020
# C_P000023
# match found:     C_P000023
# D_P000016
# match found:     D_P000016
# B_P000016
# match found:     B_P000016
# C_P000030
# match found:     C_P000030
# D_P000013
# match found:     D_P000013
# C_P000032
# match found:     C_P000032
# A_P000037
# match found:     A_P000037
# A_P000017
# match found:     A_P000017
# B_P000001
# match found:     B_P000001
# C_P000040
# match found:     C_P000040
# A_P000038
# match found:     A_P000038
# D_P000010
# match found:     D_P000010
# A_P000033
# match found:     A_P000033
# B_P000003
# match found:     B_P000003
# A_P000034
# match found:     A_P000034
# A_P000029
# match found:     A_P000029
# A_P000035
# match found:     A_P000035
# A_P000014
# match found:     A_P000014
# A_P000024
# match found:     A_P000024
# D_P000017
# match found:     D_P000017
# D_P000004
# match found:     D_P000004
# C_P000038
# match found:     C_P000038
# B_P000002
# match found:     B_P000002
# B_P000009
# match found:     B_P000009
# B_P000020
# match found:     B_P000020
# C_P000025
# match found:     C_P000025
# A_P000022
# match found:     A_P000022
# C_P000027
# match found:     C_P000027
# B_P000017
# match found:     B_P000017
# B_P000010
# match found:     B_P000010
# D_P000014
# match found:     D_P000014
# D_P000002
# match found:     D_P000002
# A_P000004
# match found:     A_P000004
# A_P000030
# match found:     A_P000030
# A_P000036
# match found:     A_P000036
# D_P000011
# match found:     D_P000011
# C_P000035
# match found:     C_P000035
# D_P000005
# match found:     D_P000005
# A_P000018
# match found:     A_P000018
# A_P000007
# match found:     A_P000007
# D_P000003
# match found:     D_P000003
# C_P000031
# match found:     C_P000031
# D_P000015
# match found:     D_P000015
# B_P000019
# match found:     B_P000019
# C_P000021
# match found:     C_P000021
# B_P000015
# match found:     B_P000015
# B_P000013
# match found:     B_P000013
# B_P000011
# match found:     B_P000011
# C_P000028
# match found:     C_P000028
# C_P000036
# match found:     C_P000036
# D_P000001
# match found:     D_P000001
# B_P000012
# match found:     B_P000012
# C_P000034
# match found:     C_P000034
# D_P000019
# match found:     D_P000019
# D_P000006
# match found:     D_P000006
# C_P000022
# match found:     C_P000022
# A_P000011
# match found:     A_P000011
# D_P000007
# match found:     D_P000007
# D_P000009
# match found:     D_P000009
# A_P000031
# match found:     A_P000031
# A_P000002
# match found:     A_P000002
